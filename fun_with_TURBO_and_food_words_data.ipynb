# %% [markdown]
# ## install anaconda -> http://continuum.io/downloads

# %%
import pandas as pd

# %% [markdown]
# ## fun files!

# %%
# !dir TURBO.csv food_words.csv
# Out:
# food_words.csv	TURBO.csv

# %% [markdown]
# ### load

# %%
TURBO_DF = pd.read_csv('TURBO.csv')

# %% [markdown]
# ### preview

# %%
pd.options.display.max_columns = len(TURBO_DF.columns) # assuming it's 32 columns a priori
TURBO_DF.head()
# Out:
#                                           attributes             business_id  \
# 0  {u'Alcohol': u'full_bar', u'Noise Level': u'av...  mxrXVZWc6PWk81gvOVNOUw
# 1  {u'Alcohol': u'beer_and_wine', u'Noise Level':...  z3yFuLVrmH-3RJruPEMYKw
# 2  {u'Alcohol': u'beer_and_wine', u'Noise Level':...  z3yFuLVrmH-3RJruPEMYKw
# 3  {u'Alcohol': u'beer_and_wine', u'Noise Level':...  z3yFuLVrmH-3RJruPEMYKw
# 4  {u'Alcohol': u'beer_and_wine', u'Noise Level':...  z3yFuLVrmH-3RJruPEMYKw
#
#                                   categories        city  \
# 0      [American (Traditional), Restaurants]  Scottsdale
# 1  [Delis, Restaurants, Sandwiches, Italian]  Scottsdale
# 2  [Delis, Restaurants, Sandwiches, Italian]  Scottsdale
# 3  [Delis, Restaurants, Sandwiches, Italian]  Scottsdale
# 4  [Delis, Restaurants, Sandwiches, Italian]  Scottsdale
#
#                                         full_address  \
# 0  4800 N Scottsdale Rd\nSte 1700\nScottsdale, AZ...
# ...

# %% [markdown]
# ### play

# %%
TURBO_DF[['business_name', 'review_stars', 'user_id']]
# Out:
#                                            business_name  review_stars  \
# 0                                           Roaring Fork             5
# 1                              Defalco's Italian Grocery             5
# 2                              Defalco's Italian Grocery             5
# 3                              Defalco's Italian Grocery             5
# 4                              Defalco's Italian Grocery             5
# 5                              Defalco's Italian Grocery             5
# 6                              Defalco's Italian Grocery             5
# 7                          Bandung Indonesian Restaurant             3
# 8                               Monty's Blue Plate Diner             2
# 9                               Monty's Blue Plate Diner             3
# 10                                Sophia's Bakery & Cafe             4
# 11                                       Weary Traveler              3
# ...

# %% [markdown]
# ##bonus! ~5K food-related words

# %%
FOOD_WORDS = pd.Series.from_csv('food_words.csv', sep='\n', header=False, index_col=None)
(FOOD_WORDS)
# Out:
# 0                bon bon chicken
# 1               deep fried papad
# 2                  sardalya tava
# 3                     mixed nuts
# 4                 macadamia nuts
# 5                      red eye75
# 6                    ekmek kaday
# 7                cuisinesalad is
# 8                           negi
# 9                  lunggoi katsa
# 10               jelly cream pie
# 11                uporridge is a
# 12            salzburger nockerl
# 13                 brunede karto
# 14                      suan cai
# 15               biscuit tortoni
# 16      thanksgiving songchapter
# 17                      kabkabou
# 18                  blt cocktail
# 19         nagasariravioli being
# 20           gansito snack cakes
# 21                pastel de tres
# 22                agnolotti is a
# 23               raw beef dishes
# 24         silver needle noodles
# 25                     ramen and
# 26                  kermit lynch
# 27            vegetable sandwich
# ...
